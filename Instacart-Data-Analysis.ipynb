# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()

# %% [markdown]
# ### Reading the datasets

# %%
order_products_train_df = pd.read_csv("./data/order_products__train.csv")
order_products_prior_df = pd.read_csv("./data/order_products__prior.csv")
orders_df = pd.read_csv("./data/orders.csv")
products_df = pd.read_csv("./data/products.csv")
aisles_df = pd.read_csv("./data/aisles.csv")
departments_df = pd.read_csv("./data/departments.csv")

# %%
order_products_prior_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
order_products_train_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %% [markdown]
# ### creating a datframe that will contain only prior information

# %%
order_products_prior_df = pd.merge(order_products_prior_df, products_df, on='product_id', how='left')
order_products_prior_df = pd.merge(order_products_prior_df, aisles_df, on='aisle_id', how='left')
order_products_prior_df = pd.merge(order_products_prior_df, departments_df, on='department_id', how='left')

# %%
cnt_srs = order_products_prior_df['product_name'].value_counts().reset_index().head(20)
cnt_srs.columns = ['product_name', 'frequency_count']
cnt_srs
# Out:
#                 product_name  frequency_count
# 0                     Banana           472565
# 1     Bag of Organic Bananas           379450
# 2       Organic Strawberries           264683
# 3       Organic Baby Spinach           241921
# 4       Organic Hass Avocado           213584
# 5            Organic Avocado           176815
# 6                Large Lemon           152657
# 7               Strawberries           142951
# 8                      Limes           140627
# 9         Organic Whole Milk           137905
# 10       Organic Raspberries           137057
# 11      Organic Yellow Onion           113426
# 12            Organic Garlic           109778
# 13          Organic Zucchini           104823
# 14       Organic Blueberries           100060
# 15            Cucumber Kirby            97315
# 16        Organic Fuji Apple            89632
# 17             Organic Lemon            87746
# 18  Apple Honeycrisp Organic            85020
# 19    Organic Grape Tomatoes            84255

# %%
plt.figure(figsize=(15,8))
sns.barplot(cnt_srs.frequency_count, cnt_srs.product_name)
plt.tight_layout()
plt.xlabel('Frequency (count)', fontsize=12)
plt.ylabel('Product Name', fontsize=12)
plt.title('Product Frequency Chart', fontsize=15)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Product Frequency Chart')

# %% [markdown]
# Most of them are organic products! Also majority of them are fruits.

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ### Creating features related to the users. i.e using user_id

# %%
orders = orders_df.merge(order_products_prior_df, on = 'order_id')

# %%
orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  \
# 0                                     Soda        77              7
# 1  Organic Unsweetened Vanilla Almond Milk        91             16
# 2                      Original Beef Jerky        23             19
# 3               Aged White Cheddar Popcorn        23             19
# 4         XL Pick-A-Size Paper Towel Rolls        54             17
#
#              aisle  department
# 0      soft drinks   beverages
# 1  soy lactosefree  dairy eggs
# 2    popcorn jerky      snacks
# 3    popcorn jerky      snacks
# 4      paper goods   household

# %%
user_orders_count = orders.groupby('user_id')[ 'order_number'].max().to_frame('user_orders').reset_index()

# %%
user_orders_count.sort_values(by ='user_orders', ascending=False)
# Out:
#         user_id  user_orders
# 152339   152340           99
# 185640   185641           99
# 185523   185524           99
# 81677     81678           99
# 70921     70922           99
# ...         ...          ...
# 13045     13046            3
# 70207     70208            3
# 111439   111440            3
# 31761     31762            3
# 47979     47980            3
#
# [206209 rows x 2 columns]

# %%
plt.figure(figsize=(10,6))
bins = [0,21, 71, 91]
labels = ['less than 20', '21-70' , 'more than 70']
user_orders_count_bin = pd.cut(user_orders_count['user_orders'], bins = bins, labels= labels, right= False)
sns.countplot(user_orders_count_bin.values)
plt.xlabel('Number of orders', fontsize=12)
plt.ylabel('User count', fontsize=12)
plt.title('User order-wise segmentation', fontsize=15)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'User order-wise segmentation')

# %%
products_per_order = orders.groupby(['user_id', 'order_id'])['product_id'].count().to_frame('total_products_ordered').reset_index()

# %%
products_per_order
# Out:
#          user_id  order_id  total_products_ordered
# 0              1    431534                       8
# 1              1    473747                       5
# 2              1    550135                       5
# 3              1   2254736                       5
# 4              1   2295261                       6
# ...          ...       ...                     ...
# 3214869   206209   2307371                       3
# 3214870   206209   2558525                       3
# 3214871   206209   2977660                       9
# 3214872   206209   3154581                      13
# 3214873   206209   3186442                       2
#
# [3214874 rows x 3 columns]

# %%
avg_products_per_order = products_per_order.groupby('user_id')['total_products_ordered'].mean().to_frame('avg_products_in_an_order').reset_index()

# %%
avg_products_per_order
# Out:
#         user_id  avg_products_in_an_order
# 0             1                  5.900000
# 1             2                 13.928571
# 2             3                  7.333333
# 3             4                  3.600000
# 4             5                  9.250000
# ...         ...                       ...
# 206204   206205                 10.666667
# 206205   206206                  4.253731
# 206206   206207                 13.937500
# 206207   206208                 13.816327
# 206208   206209                  9.923077
#
# [206209 rows x 2 columns]

# %%
user_orders = user_orders_count.merge(avg_products_per_order, on= 'user_id', how='left')

# %%
user_orders
# Out:
#         user_id  user_orders  avg_products_in_an_order
# 0             1           10                  5.900000
# 1             2           14                 13.928571
# 2             3           12                  7.333333
# 3             4            5                  3.600000
# 4             5            4                  9.250000
# ...         ...          ...                       ...
# 206204   206205            3                 10.666667
# 206205   206206           67                  4.253731
# 206206   206207           16                 13.937500
# 206207   206208           49                 13.816327
# 206208   206209           13                  9.923077
#
# [206209 rows x 3 columns]

# %% [markdown]
# ### Creating features related to the products using product_id.

# %%
products_df
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49683       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49684       49685                 En Croute Roast Hazelnut Cranberry
# 49685       49686                                   Artisan Baguette
# 49686       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49687       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id
# 0            61             19
# 1           104             13
# 2            94              7
# 3            38              1
# 4             5             13
# ...         ...            ...
# 49683       124              5
# 49684        42              1
# 49685       112              3
# 49686        41              8
# 49687        73             11
#
# [49688 rows x 4 columns]

# %%
products =  products_df.copy()
products['organic/non-organic'] = products_df.product_name.apply(lambda x: 'organic' if 'organic' in x.lower() else 'non-organic')
products.drop(['product_name', 'aisle_id', 'department_id'], axis = 1, inplace = True)

# %%
order_products = order_products_prior_df.merge(products, on = 'product_id', how = 'left')

# %%
#order_products['organic/non-organic'].value_counts(normalize = True) * 100
plt.figure(figsize=(8,6))
sns.barplot(order_products['organic/non-organic'].value_counts().index,(order_products['organic/non-organic'].value_counts(normalize=True)*100).values)
plt.xlabel('organics/non-organics', fontsize=12)
plt.ylabel('Percentage(%)', fontsize=12)
plt.title('organic vs non-organic %', fontsize=15)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'organic vs non-organic %')

# %%
organic_vs_non_reorder_perc = order_products_prior_df.merge(products, on ='product_id', how= 'left').groupby('organic/non-organic')['reordered'].aggregate('mean')

# %%
plt.figure(figsize=(8,6))
sns.barplot(organic_vs_non_reorder_perc.index,(organic_vs_non_reorder_perc.values * 100))
plt.xlabel('organics/non-organics', fontsize=12)
plt.ylabel('Percentage(%)', fontsize=12)
plt.title('organic vs non-organic reorder (%)', fontsize=15)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'organic vs non-organic reorder (%)')

# %%
reorder_freq = order_products_prior_df.groupby('department')['reordered'].aggregate('mean').reset_index()
plt.figure(figsize=(20,8))
sns.pointplot(reorder_freq['department'].values,reorder_freq['reordered'].values * 100)
plt.xticks(rotation = 'vertical')
plt.xlabel('Departments', fontsize= 12)
plt.ylabel(' Reorder(%)', fontsize = 12)
plt.title('Department wise Reorder(%)', fontsize = 15)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Department wise Reorder(%)')

# %% [markdown]
# Personal Care lowest reordering percentage and dairy eggs highest

# %%
products_count =  orders.groupby('product_id')['reordered'].aggregate(['count','mean']).reset_index()

# %%
products_count.rename(columns = {'count':'reordered_count', 'mean': 'reordered_ratio'}, inplace=True)

# %% [markdown]
# ### Creating user-product features.

# %%
user_product_info = orders.groupby(['user_id', 'product_id'])['order_id'].count().to_frame('products_count_user_in_order').reset_index()

# %%
user_product_info
# Out:
#           user_id  product_id  products_count_user_in_order
# 0               1         196                            10
# 1               1       10258                             9
# 2               1       10326                             1
# 3               1       12427                            10
# 4               1       13032                             3
# ...           ...         ...                           ...
# 13307948   206209       43961                             3
# 13307949   206209       44325                             1
# 13307950   206209       48370                             1
# 13307951   206209       48697                             1
# 13307952   206209       48742                             2
#
# [13307953 rows x 3 columns]

# %%
user_product_avg_info = orders.groupby(['user_id', 'product_id'])['reordered'].mean().to_frame('products_count_user_in_order_mean').reset_index()

# %%
user_product_avg_info
# Out:
#           user_id  product_id  products_count_user_in_order_mean
# 0               1         196                           0.900000
# 1               1       10258                           0.888889
# 2               1       10326                           0.000000
# 3               1       12427                           0.900000
# 4               1       13032                           0.666667
# ...           ...         ...                                ...
# 13307948   206209       43961                           0.666667
# 13307949   206209       44325                           0.000000
# 13307950   206209       48370                           0.000000
# 13307951   206209       48697                           0.000000
# 13307952   206209       48742                           0.500000
#
# [13307953 rows x 3 columns]

# %%
user_product_avg_count_info = user_product_info.merge(user_product_avg_info, on = ['user_id', 'product_id'])
user_product_avg_count_info
# Out:
#           user_id  product_id  products_count_user_in_order  \
# 0               1         196                            10
# 1               1       10258                             9
# 2               1       10326                             1
# 3               1       12427                            10
# 4               1       13032                             3
# ...           ...         ...                           ...
# 13307948   206209       43961                             3
# 13307949   206209       44325                             1
# 13307950   206209       48370                             1
# 13307951   206209       48697                             1
# 13307952   206209       48742                             2
#
#           products_count_user_in_order_mean
# 0                                  0.900000
# 1                                  0.888889
# 2                                  0.000000
# 3                                  0.900000
# 4                                  0.666667
# ...                                     ...
# 13307948                           0.666667
# 13307949                           0.000000
# 13307950                           0.000000
# 13307951                           0.000000
# 13307952                           0.500000
#
# [13307953 rows x 4 columns]

# %%
total_data =  user_product_avg_count_info.merge(user_orders, on='user_id',how='left')
total_data
# Out:
#           user_id  product_id  products_count_user_in_order  \
# 0               1         196                            10
# 1               1       10258                             9
# 2               1       10326                             1
# 3               1       12427                            10
# 4               1       13032                             3
# ...           ...         ...                           ...
# 13307948   206209       43961                             3
# 13307949   206209       44325                             1
# 13307950   206209       48370                             1
# 13307951   206209       48697                             1
# 13307952   206209       48742                             2
#
#           products_count_user_in_order_mean  user_orders  \
# 0                                  0.900000           10
# 1                                  0.888889           10
# 2                                  0.000000           10
# 3                                  0.900000           10
# 4                                  0.666667           10
# ...                                     ...          ...
# 13307948                           0.666667           13
# 13307949                           0.000000           13
# 13307950                           0.000000           13
# 13307951                           0.000000           13
# 13307952                           0.500000           13
#
#           avg_products_in_an_order
# 0                         5.900000
# 1                         5.900000
# 2                         5.900000
# 3                         5.900000
# 4                         5.900000
# ...                            ...
# 13307948                  9.923077
# 13307949                  9.923077
# 13307950                  9.923077
# 13307951                  9.923077
# 13307952                  9.923077
#
# [13307953 rows x 6 columns]

# %%
total_data = total_data.merge(products_count, on ='product_id')
total_data
# Out:
#           user_id  product_id  products_count_user_in_order  \
# 0               1         196                            10
# 1              15         196                             5
# 2              19         196                             3
# 3              21         196                             1
# 4              31         196                             2
# ...           ...         ...                           ...
# 13307948   200463        8682                             1
# 13307949   203389        8682                             1
# 13307950   202557       43553                            13
# 13307951   203436       42338                             2
# 13307952   205420       28818                             1
#
#           products_count_user_in_order_mean  user_orders  \
# 0                                  0.900000           10
# 1                                  0.800000           22
# 2                                  0.666667            9
# 3                                  0.000000           33
# 4                                  0.500000           20
# ...                                     ...          ...
# 13307948                           0.000000            4
# 13307949                           0.000000           17
# 13307950                           0.923077           31
# 13307951                           0.500000            3
# 13307952                           0.000000           16
#
#           avg_products_in_an_order  reordered_count  reordered_ratio
# 0                         5.900000            35791         0.776480
# 1                         3.272727            35791         0.776480
# 2                        22.666667            35791         0.776480
# 3                         6.212121            35791         0.776480
# 4                        14.950000            35791         0.776480
# ...                            ...              ...              ...
# 13307948                  9.500000                2         0.000000
# 13307949                 11.705882                2         0.000000
# 13307950                 10.838710               13         0.923077
# 13307951                 12.666667                2         0.500000
# 13307952                  7.375000                1         0.000000
#
# [13307953 rows x 8 columns]

# %%
order_future = orders_df.loc[((orders_df.eval_set == 'train') | (orders_df.eval_set == 'test')), ['user_id', 'eval_set', 'order_id']]
order_future
# Out:
#          user_id eval_set  order_id
# 10             1    train   1187899
# 25             2    train   1492625
# 38             3     test   2774568
# 44             4     test    329954
# 49             5    train   2196797
# ...          ...      ...       ...
# 3420933   206205    train   1716008
# 3421001   206206     test   1043943
# 3421018   206207     test   2821651
# 3421068   206208     test    803273
# 3421082   206209    train    272231
#
# [206209 rows x 3 columns]

# %% [markdown]
# ### Creating train and test dataset.

# %%
train_test_data = total_data.merge(order_future, on='user_id', how='left')
train_test_data.head()
# Out:
#    user_id  product_id  products_count_user_in_order  \
# 0        1         196                            10
# 1       15         196                             5
# 2       19         196                             3
# 3       21         196                             1
# 4       31         196                             2
#
#    products_count_user_in_order_mean  user_orders  avg_products_in_an_order  \
# 0                           0.900000           10                  5.900000
# 1                           0.800000           22                  3.272727
# 2                           0.666667            9                 22.666667
# 3                           0.000000           33                  6.212121
# 4                           0.500000           20                 14.950000
#
#    reordered_count  reordered_ratio eval_set  order_id
# 0            35791          0.77648    train   1187899
# 1            35791          0.77648     test   2161313
# 2            35791          0.77648     test   1735923
# 3            35791          0.77648    train   1854765
# 4            35791          0.77648     test    280888

# %%
train_data =  train_test_data[train_test_data['eval_set']=='train']

# %%
train_data = train_data.merge(order_products_train_df[['product_id', 'order_id', 'reordered']], on=['product_id', 'order_id'], how='left')
train_data
# Out:
#          user_id  product_id  products_count_user_in_order  \
# 0              1         196                            10
# 1             21         196                             1
# 2             43         196                             2
# 3             52         196                            14
# 4             67         196                            19
# ...          ...         ...                           ...
# 8474656   200351       15408                             1
# 8474657   205587       15408                             1
# 8474658   203389        8682                             1
# 8474659   202557       43553                            13
# 8474660   205420       28818                             1
#
#          products_count_user_in_order_mean  user_orders  \
# 0                                 0.900000           10
# 1                                 0.000000           33
# 2                                 0.500000           11
# 3                                 0.928571           27
# 4                                 0.947368           24
# ...                                    ...          ...
# 8474656                           0.000000           11
# 8474657                           0.000000           10
# 8474658                           0.000000           17
# 8474659                           0.923077           31
# 8474660                           0.000000           16
#
#          avg_products_in_an_order  reordered_count  reordered_ratio eval_set  \
# 0                        5.900000            35791         0.776480    train
# 1                        6.212121            35791         0.776480    train
# 2                       13.363636            35791         0.776480    train
# 3                        6.259259            35791         0.776480    train
# 4                        3.375000            35791         0.776480    train
# ...                           ...              ...              ...      ...
# 8474656                  5.000000                2         0.000000    train
# 8474657                 13.200000                2         0.000000    train
# 8474658                 11.705882                2         0.000000    train
# 8474659                 10.838710               13         0.923077    train
# 8474660                  7.375000                1         0.000000    train
#
#          order_id  reordered
# 0         1187899        1.0
# 1         1854765        NaN
# 2         1864787        NaN
# 3         1647290        NaN
# 4         2757217        1.0
# ...           ...        ...
# 8474656   1768329        NaN
# 8474657   2444330        NaN
# 8474658    300189        NaN
# 8474659   2335762        NaN
# 8474660   1019981        NaN
#
# [8474661 rows x 11 columns]

# %%
train_data.reordered.fillna(0, inplace=True)

# %%
train_data = train_data.merge(products_df[['product_id', 'aisle_id','department_id']], on='product_id', how='left')

# %%
train_data
# Out:
#          user_id  product_id  products_count_user_in_order  \
# 0              1         196                            10
# 1             21         196                             1
# 2             43         196                             2
# 3             52         196                            14
# 4             67         196                            19
# ...          ...         ...                           ...
# 8474656   200351       15408                             1
# 8474657   205587       15408                             1
# 8474658   203389        8682                             1
# 8474659   202557       43553                            13
# 8474660   205420       28818                             1
#
#          products_count_user_in_order_mean  user_orders  \
# 0                                 0.900000           10
# 1                                 0.000000           33
# 2                                 0.500000           11
# 3                                 0.928571           27
# 4                                 0.947368           24
# ...                                    ...          ...
# 8474656                           0.000000           11
# 8474657                           0.000000           10
# 8474658                           0.000000           17
# 8474659                           0.923077           31
# 8474660                           0.000000           16
#
#          avg_products_in_an_order  reordered_count  reordered_ratio eval_set  \
# 0                        5.900000            35791         0.776480    train
# 1                        6.212121            35791         0.776480    train
# 2                       13.363636            35791         0.776480    train
# 3                        6.259259            35791         0.776480    train
# 4                        3.375000            35791         0.776480    train
# ...                           ...              ...              ...      ...
# 8474656                  5.000000                2         0.000000    train
# 8474657                 13.200000                2         0.000000    train
# 8474658                 11.705882                2         0.000000    train
# 8474659                 10.838710               13         0.923077    train
# 8474660                  7.375000                1         0.000000    train
#
#          order_id  reordered  aisle_id  department_id
# 0         1187899        1.0        77              7
# 1         1854765        0.0        77              7
# 2         1864787        0.0        77              7
# 3         1647290        0.0        77              7
# 4         2757217        1.0        77              7
# ...           ...        ...       ...            ...
# 8474656   1768329        0.0        20             11
# 8474657   2444330        0.0        20             11
# 8474658    300189        0.0       114             17
# 8474659   2335762        0.0        64              7
# 8474660   1019981        0.0       130             14
#
# [8474661 rows x 13 columns]

# %%
train_data.drop(['eval_set', 'order_id'], axis=1, inplace=True)

# %%
week_day =  orders.groupby('user_id')['order_dow'].agg(lambda x: pd.Series.mode(x)[0]).to_frame('day_of_week_most_ordered').reset_index()

# %%
hour_day = orders.groupby('user_id')['order_hour_of_day'].agg(lambda x: pd.Series.mode(x)[0]).to_frame('hour_of_day_most_ordered').reset_index()

# %%
train_data = train_data.merge(week_day, on='user_id', how='left')
train_data = train_data.merge(hour_day, on ='user_id', how='left')

# %%
train_data
# Out:
#          user_id  product_id  products_count_user_in_order  \
# 0              1         196                            10
# 1             21         196                             1
# 2             43         196                             2
# 3             52         196                            14
# 4             67         196                            19
# ...          ...         ...                           ...
# 8474656   200351       15408                             1
# 8474657   205587       15408                             1
# 8474658   203389        8682                             1
# 8474659   202557       43553                            13
# 8474660   205420       28818                             1
#
#          products_count_user_in_order_mean  user_orders  \
# 0                                 0.900000           10
# 1                                 0.000000           33
# 2                                 0.500000           11
# 3                                 0.928571           27
# 4                                 0.947368           24
# ...                                    ...          ...
# 8474656                           0.000000           11
# 8474657                           0.000000           10
# 8474658                           0.000000           17
# 8474659                           0.923077           31
# 8474660                           0.000000           16
#
#          avg_products_in_an_order  reordered_count  reordered_ratio  \
# 0                        5.900000            35791         0.776480
# 1                        6.212121            35791         0.776480
# 2                       13.363636            35791         0.776480
# 3                        6.259259            35791         0.776480
# 4                        3.375000            35791         0.776480
# ...                           ...              ...              ...
# 8474656                  5.000000                2         0.000000
# 8474657                 13.200000                2         0.000000
# 8474658                 11.705882                2         0.000000
# 8474659                 10.838710               13         0.923077
# 8474660                  7.375000                1         0.000000
#
#          reordered  aisle_id  department_id  day_of_week_most_ordered  \
# 0              1.0        77              7                         4
# 1              0.0        77              7                         1
# 2              0.0        77              7                         4
# 3              0.0        77              7                         1
# 4              1.0        77              7                         1
# ...            ...       ...            ...                       ...
# 8474656        0.0        20             11                         3
# 8474657        0.0        20             11                         1
# 8474658        0.0       114             17                         1
# 8474659        0.0        64              7                         4
# 8474660        0.0       130             14                         0
#
#          hour_of_day_most_ordered
# 0                               7
# 1                               9
# 2                              12
# 3                              10
# 4                              11
# ...                           ...
# 8474656                        11
# 8474657                        22
# 8474658                        10
# 8474659                        13
# 8474660                        19
#
# [8474661 rows x 13 columns]

# %%
train_data.to_csv('SAS__Train_File.csv', index = False)

# %%
test_data =  train_test_data[train_test_data['eval_set']=='test']
test_data.drop(['eval_set', 'order_id'], axis=1, inplace=True)
test_data
#final_data_test = final_data_test.set_index(['user_id', 'product_id'])

# %%
#final_data_test.reset_index(inplace=True)
test_data = test_data.merge(products_df[['product_id', 'aisle_id']], on='product_id', how='left')
test_data

# %%
test_data = test_data.merge(products_df[['product_id', 'department_id']], on='product_id', how='left')

# %%
test_data = test_data.merge(week_day, on='user_id', how='left')
test_data =  test_data.merge(hour_day, on ='user_id', how='left')

# %%
test_data.to_csv('SAS_test_file.csv', index = False)

# %% [markdown]
# ### Reading the csv file exported from SAS

# %%
results_sas_prediction = pd.read_csv('./em_save_SCORE.csv')
results_sas_prediction

# %%
results_sas_prediction.columns

# %%
results_sas_prediction.drop(['_WARN_', '_NODE_', 'Q_reordered1', 'Q_reordered0', 'V_reordered1',
       'V_reordered0', 'U_reordered', 'EM_SEGMENT', 'EM_EVENTPROBABILITY',
       'EM_PROBABILITY'], axis = 1)

# %%
results_sas_prediction.rename(columns = {'EM_CLASSIFICATION':'reorder'}, inplace = True)

# %%
test_orders = orders_df.loc[orders_df.eval_set == 'test', ['user_id', 'order_id']]
test_orders.head()

# %%
results_sas_prediction = results_sas_prediction[['product_id', 'user_id', 'reorder']]
results_sas_prediction

# %%
results_sas_prediction = results_sas_prediction.merge(test_orders, on='user_id', how='left')
results_sas_prediction

# %%
#remove user_id column
#results_sas_prediction = results_sas_prediction.drop('user_id', axis=1)

# %%
results_sas_prediction

# %%
#convert product_id as integer
results_sas_prediction['product_id'] = results_sas_prediction.product_id.astype(int)
results_sas_prediction[results_sas_prediction['user_id'] == 15]

# %%
d = dict()
for row in results_sas_prediction.itertuples():
    if row.reorder == 1:
        try:
            d[row.order_id] += ', ' + order_products_prior_df[order_products_prior_df['product_id'] == row.product_id]['product_name'].values[0]
        except:
            d[row.order_id] = order_products_prior_df[order_products_prior_df['product_id'] == row.product_id]['product_name'].values[0]

# %%
d

# %%
import csv
csv_columns = ['order_id','product_names']
cart_order_prediction = 'cart_order_prediction.csv'
with open(cart_order_prediction, 'w') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
    writer.writeheader()
    for data in d.keys():
        csvfile.write("%s,%s\n"%(data,d[data]))
